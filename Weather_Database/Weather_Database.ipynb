# %%
#Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time 

from citipy import citipy

# %% [markdown]
# ## Create a new set of 2,000 random latitudes and longitudes.
# ## Get the nearest city using the citipy module

# %%
#Create a set of 2,000 random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
coordinates = list(lat_lngs)

cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 734

# %% [markdown]
# ## Perform an API call with the OpenWeatherMap.

# %%
#Import dependencies
import requests
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    time.sleep(1)
    
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | port moresby
# Processing Record 3 of Set 1 | honningsvag
# Processing Record 4 of Set 1 | san joaquin
# Processing Record 5 of Set 1 | fare
# Processing Record 6 of Set 1 | sambava
# Processing Record 7 of Set 1 | chateaubelair
# Processing Record 8 of Set 1 | bredasdorp
# Processing Record 9 of Set 1 | cabo san lucas
# Processing Record 10 of Set 1 | cape town
# Processing Record 11 of Set 1 | victoria
# Processing Record 12 of Set 1 | tiksi
# Processing Record 13 of Set 1 | ojinaga
# Processing Record 14 of Set 1 | mataura
# Processing Record 15 of Set 1 | kralendijk
# Processing Record 16 of Set 1 | ati
# Processing Record 17 of Set 1 | punta arenas
# Processing Record 18 of Set 1 | busselton
# Processing Record 19 of Set 1 | businga
# Processing Record 20 of Set 1 | lompoc
# Processing Record 21 of Set 1 | puerto ayora
# Processing Record 22 of Set 1 | hilo
# Processing Record 23 of Set 1 | chokurdakh
# Processing Record 24 of Set 1 | peleduy
# Processing Record 25 of Set 1 | kavaratti
# Processing Record 26 of Set 1 | chapais
# Processing Record 27 of Set 1 | manokwari
# Processing Record 28 of Set 1 | mahebourg
# Processing Record 29 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 1 | laguna
# Processing Record 31 of Set 1 | sao filipe
# Processing Record 32 of Set 1 | rungata
# City not found. Skipping...
# Processing Record 33 of Set 1 | castro
# Processing Record 34 of Set 1 | jamestown
# Processing Record 35 of Set 1 | thompson
# Processing Record 36 of Set 1 | borovoy
# Processing Record 37 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 38 of Set 1 | avarua
# Processing Record 39 of Set 1 | cayenne
# Processing Record 40 of Set 1 | lagoa
# Processing Record 41 of Set 1 | saskylakh
# Processing Record 42 of Set 1 | shkotovo-22
# City not found. Skipping...
# Processing Record 43 of Set 1 | upernavik
# Processing Record 44 of Set 1 | khani
# Processing Record 45 of Set 1 | vokhma
# Processing Record 46 of Set 1 | norman wells
# Processing Record 47 of Set 1 | albany
# Processing Record 48 of Set 1 | rockland
# Processing Record 49 of Set 1 | airai
# Processing Record 50 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 1 of Set 2 | los llanos de aridane
# Processing Record 2 of Set 2 | tuktoyaktuk
# Processing Record 3 of Set 2 | paris
# Processing Record 4 of Set 2 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 5 of Set 2 | umm lajj
# Processing Record 6 of Set 2 | aklavik
# Processing Record 7 of Set 2 | khorramabad
# Processing Record 8 of Set 2 | ushuaia
# Processing Record 9 of Set 2 | half moon bay
# Processing Record 10 of Set 2 | fortuna
# Processing Record 11 of Set 2 | sarakhs
# Processing Record 12 of Set 2 | mehamn
# Processing Record 13 of Set 2 | saint-pierre
# Processing Record 14 of Set 2 | vaini
# Processing Record 15 of Set 2 | olavarria
# Processing Record 16 of Set 2 | bethanien
# Processing Record 17 of Set 2 | san quintin
# Processing Record 18 of Set 2 | san cristobal
# Processing Record 19 of Set 2 | hobart
# Processing Record 20 of Set 2 | shumskiy
# Processing Record 21 of Set 2 | torbay
# Processing Record 22 of Set 2 | kapaa
# Processing Record 23 of Set 2 | geraldton
# Processing Record 24 of Set 2 | portland
# Processing Record 25 of Set 2 | ribeira grande
# Processing Record 26 of Set 2 | chivay
# Processing Record 27 of Set 2 | khatanga
# Processing Record 28 of Set 2 | faanui
# Processing Record 29 of Set 2 | merauke
# Processing Record 30 of Set 2 | codrington
# Processing Record 31 of Set 2 | sorland
# Processing Record 32 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 33 of Set 2 | guerrero negro
# Processing Record 34 of Set 2 | te anau
# Processing Record 35 of Set 2 | yellowknife
# Processing Record 36 of Set 2 | new norfolk
# Processing Record 37 of Set 2 | ploemeur
# Processing Record 38 of Set 2 | monte alegre
# Processing Record 39 of Set 2 | abeche
# Processing Record 40 of Set 2 | antigonish
# Processing Record 41 of Set 2 | port elizabeth
# Processing Record 42 of Set 2 | henties bay
# Processing Record 43 of Set 2 | kankaanpaa
# Processing Record 44 of Set 2 | clyde river
# Processing Record 45 of Set 2 | saldanha
# Processing Record 46 of Set 2 | griffith
# Processing Record 47 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 48 of Set 2 | pangnirtung
# Processing Record 49 of Set 2 | hamilton
# Processing Record 50 of Set 2 | lebu
# Processing Record 1 of Set 3 | flin flon
# Processing Record 2 of Set 3 | iqaluit
# Processing Record 3 of Set 3 | ketchikan
# Processing Record 4 of Set 3 | kudahuvadhoo
# Processing Record 5 of Set 3 | prabumulih
# Processing Record 6 of Set 3 | georgetown
# Processing Record 7 of Set 3 | hermanus
# Processing Record 8 of Set 3 | sitka
# Processing Record 9 of Set 3 | anadyr
# Processing Record 10 of Set 3 | cherskiy
# Processing Record 11 of Set 3 | quelimane
# Processing Record 12 of Set 3 | butaritari
# Processing Record 13 of Set 3 | romny
# Processing Record 14 of Set 3 | nantucket
# Processing Record 15 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 16 of Set 3 | shestakovo
# Processing Record 17 of Set 3 | saint-philippe
# Processing Record 18 of Set 3 | longyearbyen
# Processing Record 19 of Set 3 | sao gabriel da cachoeira
# Processing Record 20 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 21 of Set 3 | haines junction
# Processing Record 22 of Set 3 | vardo
# Processing Record 23 of Set 3 | lorengau
# Processing Record 24 of Set 3 | east london
# Processing Record 25 of Set 3 | kavieng
# Processing Record 26 of Set 3 | aksu
# Processing Record 27 of Set 3 | campo de criptana
# Processing Record 28 of Set 3 | harper
# Processing Record 29 of Set 3 | kaitangata
# Processing Record 30 of Set 3 | lavrentiya
# Processing Record 31 of Set 3 | kruisfontein
# Processing Record 32 of Set 3 | ancud
# Processing Record 33 of Set 3 | mago
# Processing Record 34 of Set 3 | bathsheba
# Processing Record 35 of Set 3 | karratha
# Processing Record 36 of Set 3 | sumter
# Processing Record 37 of Set 3 | provideniya
# Processing Record 38 of Set 3 | bethel
# Processing Record 39 of Set 3 | bengkulu
# Processing Record 40 of Set 3 | zhurivka
# Processing Record 41 of Set 3 | sechura
# Processing Record 42 of Set 3 | qaanaaq
# Processing Record 43 of Set 3 | ailigandi
# Processing Record 44 of Set 3 | chuy
# Processing Record 45 of Set 3 | waldoboro
# Processing Record 46 of Set 3 | kropotkin
# Processing Record 47 of Set 3 | athabasca
# Processing Record 48 of Set 3 | puri
# Processing Record 49 of Set 3 | atuona
# Processing Record 50 of Set 3 | padang
# Processing Record 1 of Set 4 | aswan
# Processing Record 2 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 4 | hasaki
# Processing Record 4 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 5 of Set 4 | kalmunai
# Processing Record 6 of Set 4 | skibbereen
# Processing Record 7 of Set 4 | koumra
# Processing Record 8 of Set 4 | togul
# Processing Record 9 of Set 4 | porto novo
# Processing Record 10 of Set 4 | henderson
# Processing Record 11 of Set 4 | hithadhoo
# Processing Record 12 of Set 4 | hambantota
# Processing Record 13 of Set 4 | atikokan
# Processing Record 14 of Set 4 | severo-kurilsk
# Processing Record 15 of Set 4 | ostrovnoy
# Processing Record 16 of Set 4 | northam
# Processing Record 17 of Set 4 | cumaribo
# City not found. Skipping...
# Processing Record 18 of Set 4 | lerwick
# Processing Record 19 of Set 4 | plettenberg bay
# Processing Record 20 of Set 4 | saint george
# Processing Record 21 of Set 4 | dikson
# Processing Record 22 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 23 of Set 4 | comodoro rivadavia
# Processing Record 24 of Set 4 | tallahassee
# Processing Record 25 of Set 4 | inuvik
# Processing Record 26 of Set 4 | eureka
# Processing Record 27 of Set 4 | port alfred
# Processing Record 28 of Set 4 | nacala
# Processing Record 29 of Set 4 | bilibino
# Processing Record 30 of Set 4 | arraial do cabo
# Processing Record 31 of Set 4 | ilulissat
# Processing Record 32 of Set 4 | hay river
# Processing Record 33 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 34 of Set 4 | mocuba
# Processing Record 35 of Set 4 | chabahar
# Processing Record 36 of Set 4 | bluff
# Processing Record 37 of Set 4 | lehi
# Processing Record 38 of Set 4 | chau doc
# Processing Record 39 of Set 4 | pecos
# Processing Record 40 of Set 4 | naze
# Processing Record 41 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 42 of Set 4 | mount gambier
# Processing Record 43 of Set 4 | barrow
# Processing Record 44 of Set 4 | villa san giovanni
# Processing Record 45 of Set 4 | ibra
# Processing Record 46 of Set 4 | birao
# Processing Record 47 of Set 4 | cidreira
# Processing Record 48 of Set 4 | kieta
# Processing Record 49 of Set 4 | dzhusaly
# City not found. Skipping...
# Processing Record 50 of Set 4 | kodiak
# Processing Record 1 of Set 5 | lensk
# Processing Record 2 of Set 5 | hervey bay
# Processing Record 3 of Set 5 | maniitsoq
# Processing Record 4 of Set 5 | vila velha
# Processing Record 5 of Set 5 | carnarvon
# Processing Record 6 of Set 5 | taoudenni
# Processing Record 7 of Set 5 | ouesso
# Processing Record 8 of Set 5 | aleksandrov gay
# Processing Record 9 of Set 5 | tilichiki
# Processing Record 10 of Set 5 | skagastrond
# City not found. Skipping...
# Processing Record 11 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 12 of Set 5 | zhaocheng
# City not found. Skipping...
# Processing Record 13 of Set 5 | mar del plata
# Processing Record 14 of Set 5 | srednekolymsk
# Processing Record 15 of Set 5 | pirojpur
# Processing Record 16 of Set 5 | helong
# Processing Record 17 of Set 5 | calvinia
# Processing Record 18 of Set 5 | lotofaga
# Processing Record 19 of Set 5 | sayyan
# Processing Record 20 of Set 5 | sur
# Processing Record 21 of Set 5 | tuburan
# Processing Record 22 of Set 5 | roebourne
# Processing Record 23 of Set 5 | tawkar
# City not found. Skipping...
# Processing Record 24 of Set 5 | lincoln
# Processing Record 25 of Set 5 | kamphaeng phet
# Processing Record 26 of Set 5 | tabialan
# City not found. Skipping...
# Processing Record 27 of Set 5 | paranaiba
# Processing Record 28 of Set 5 | shaoguan
# Processing Record 29 of Set 5 | mayari
# City not found. Skipping...
# Processing Record 30 of Set 5 | esperance
# Processing Record 31 of Set 5 | rawson
# Processing Record 32 of Set 5 | mayo
# Processing Record 33 of Set 5 | roma
# Processing Record 34 of Set 5 | lisala
# Processing Record 35 of Set 5 | channel-port aux basques
# Processing Record 36 of Set 5 | chengde
# Processing Record 37 of Set 5 | warangal
# Processing Record 38 of Set 5 | falealupo
# City not found. Skipping...
# Processing Record 39 of Set 5 | bubaque
# Processing Record 40 of Set 5 | narsipatnam
# Processing Record 41 of Set 5 | san-pedro
# Processing Record 42 of Set 5 | soller
# Processing Record 43 of Set 5 | sobradinho
# Processing Record 44 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 45 of Set 5 | chapeco
# Processing Record 46 of Set 5 | dickinson
# Processing Record 47 of Set 5 | nanortalik
# Processing Record 48 of Set 5 | traralgon
# Processing Record 49 of Set 5 | mayskiy
# Processing Record 50 of Set 5 | contamana
# Processing Record 1 of Set 6 | udachnyy
# Processing Record 2 of Set 6 | bagdarin
# Processing Record 3 of Set 6 | madina
# Processing Record 4 of Set 6 | tayshet
# Processing Record 5 of Set 6 | tarudant
# City not found. Skipping...
# Processing Record 6 of Set 6 | fairbanks
# Processing Record 7 of Set 6 | dayong
# Processing Record 8 of Set 6 | port blair
# Processing Record 9 of Set 6 | wajima
# Processing Record 10 of Set 6 | zhaotong
# Processing Record 11 of Set 6 | constitucion
# Processing Record 12 of Set 6 | takoradi
# Processing Record 13 of Set 6 | winnemucca
# Processing Record 14 of Set 6 | jimenez
# Processing Record 15 of Set 6 | bolshaya dzhalga
# Processing Record 16 of Set 6 | kholodnyy
# Processing Record 17 of Set 6 | formoso do araguaia
# City not found. Skipping...
# Processing Record 18 of Set 6 | mayumba
# Processing Record 19 of Set 6 | coahuayana
# Processing Record 20 of Set 6 | gigmoto
# Processing Record 21 of Set 6 | botad
# Processing Record 22 of Set 6 | tomatlan
# Processing Record 23 of Set 6 | salalah
# Processing Record 24 of Set 6 | wanning
# Processing Record 25 of Set 6 | alugan
# Processing Record 26 of Set 6 | richards bay
# Processing Record 27 of Set 6 | luderitz
# Processing Record 28 of Set 6 | nome
# Processing Record 29 of Set 6 | saint-joseph
# Processing Record 30 of Set 6 | isangel
# Processing Record 31 of Set 6 | plaster rock
# Processing Record 32 of Set 6 | cap malheureux
# Processing Record 33 of Set 6 | tsumeb
# Processing Record 34 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 35 of Set 6 | saint-gaudens
# Processing Record 36 of Set 6 | rio grande
# Processing Record 37 of Set 6 | santa rosalia
# Processing Record 38 of Set 6 | mikhaylovka
# Processing Record 39 of Set 6 | novo aripuana
# Processing Record 40 of Set 6 | uvinza
# Processing Record 41 of Set 6 | komsomolskiy
# Processing Record 42 of Set 6 | hendijan
# City not found. Skipping...
# Processing Record 43 of Set 6 | qaqortoq
# Processing Record 44 of Set 6 | chandbali
# Processing Record 45 of Set 6 | nikolskoye
# Processing Record 46 of Set 6 | touros
# Processing Record 47 of Set 6 | webuye
# Processing Record 48 of Set 6 | atar
# Processing Record 49 of Set 6 | sao felix do xingu
# Processing Record 50 of Set 6 | talcahuano
# Processing Record 1 of Set 7 | adrar
# Processing Record 2 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 3 of Set 7 | kilindoni
# Processing Record 4 of Set 7 | povenets
# Processing Record 5 of Set 7 | bucerias
# Processing Record 6 of Set 7 | tonj
# Processing Record 7 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 8 of Set 7 | ust-kuyga
# Processing Record 9 of Set 7 | arkhara
# Processing Record 10 of Set 7 | san antonio
# Processing Record 11 of Set 7 | inhambane
# Processing Record 12 of Set 7 | karasjok
# Processing Record 13 of Set 7 | leningradskiy
# Processing Record 14 of Set 7 | kharod
# Processing Record 15 of Set 7 | teahupoo
# Processing Record 16 of Set 7 | preston
# Processing Record 17 of Set 7 | dunedin
# Processing Record 18 of Set 7 | nalut
# Processing Record 19 of Set 7 | viedma
# Processing Record 20 of Set 7 | waipawa
# Processing Record 21 of Set 7 | vila franca do campo
# Processing Record 22 of Set 7 | pochutla
# Processing Record 23 of Set 7 | labuhan
# Processing Record 24 of Set 7 | walvis bay
# Processing Record 25 of Set 7 | marsa matruh
# Processing Record 26 of Set 7 | baghdad
# Processing Record 27 of Set 7 | vanimo
# Processing Record 28 of Set 7 | turbat
# Processing Record 29 of Set 7 | wajid
# Processing Record 30 of Set 7 | baiyin
# Processing Record 31 of Set 7 | pevek
# Processing Record 32 of Set 7 | anloga
# Processing Record 33 of Set 7 | alyangula
# Processing Record 34 of Set 7 | camacha
# Processing Record 35 of Set 7 | fort nelson
# Processing Record 36 of Set 7 | dondo
# Processing Record 37 of Set 7 | mergui
# City not found. Skipping...
# Processing Record 38 of Set 7 | beyneu
# Processing Record 39 of Set 7 | yaring
# Processing Record 40 of Set 7 | sayat
# Processing Record 41 of Set 7 | samarai
# Processing Record 42 of Set 7 | nguiu
# City not found. Skipping...
# Processing Record 43 of Set 7 | chicama
# Processing Record 44 of Set 7 | kismayo
# Processing Record 45 of Set 7 | coquimbo
# Processing Record 46 of Set 7 | iwaki
# Processing Record 47 of Set 7 | nefteyugansk
# Processing Record 48 of Set 7 | noumea
# Processing Record 49 of Set 7 | cockburn town
# Processing Record 50 of Set 7 | road town
# Processing Record 1 of Set 8 | mandalgovi
# Processing Record 2 of Set 8 | novaya malykla
# Processing Record 3 of Set 8 | cullera
# Processing Record 4 of Set 8 | klaksvik
# Processing Record 5 of Set 8 | yelizovo
# Processing Record 6 of Set 8 | ternate
# Processing Record 7 of Set 8 | malatya
# Processing Record 8 of Set 8 | bambous virieux
# Processing Record 9 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 10 of Set 8 | westport
# Processing Record 11 of Set 8 | jalu
# Processing Record 12 of Set 8 | poltavka
# Processing Record 13 of Set 8 | dudinka
# Processing Record 14 of Set 8 | matane
# Processing Record 15 of Set 8 | jumla
# Processing Record 16 of Set 8 | malwan
# City not found. Skipping...
# Processing Record 17 of Set 8 | banda aceh
# Processing Record 18 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 19 of Set 8 | palmer
# Processing Record 20 of Set 8 | bagotville
# Processing Record 21 of Set 8 | kansanshi
# Processing Record 22 of Set 8 | lopez jaena
# Processing Record 23 of Set 8 | kodinsk
# Processing Record 24 of Set 8 | superior
# Processing Record 25 of Set 8 | prykolotne
# Processing Record 26 of Set 8 | evensk
# Processing Record 27 of Set 8 | manggar
# Processing Record 28 of Set 8 | bonthe
# Processing Record 29 of Set 8 | mrirt
# City not found. Skipping...
# Processing Record 30 of Set 8 | bushehr
# Processing Record 31 of Set 8 | santa cruz
# Processing Record 32 of Set 8 | ixtapa
# Processing Record 33 of Set 8 | alcacer do sal
# Processing Record 34 of Set 8 | ahipara
# Processing Record 35 of Set 8 | bereda
# Processing Record 36 of Set 8 | katsuura
# Processing Record 37 of Set 8 | lodja
# Processing Record 38 of Set 8 | dingle
# Processing Record 39 of Set 8 | balkhash
# Processing Record 40 of Set 8 | sibolga
# Processing Record 41 of Set 8 | genhe
# Processing Record 42 of Set 8 | vao
# Processing Record 43 of Set 8 | labutta
# City not found. Skipping...
# Processing Record 44 of Set 8 | wonthaggi
# Processing Record 45 of Set 8 | totness
# Processing Record 46 of Set 8 | general pico
# Processing Record 47 of Set 8 | septemes-les-vallons
# Processing Record 48 of Set 8 | gurupa
# Processing Record 49 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 50 of Set 8 | callaway
# Processing Record 1 of Set 9 | umm kaddadah
# Processing Record 2 of Set 9 | talnakh
# Processing Record 3 of Set 9 | pinega
# Processing Record 4 of Set 9 | gravdal
# Processing Record 5 of Set 9 | ocos
# Processing Record 6 of Set 9 | joao pinheiro
# Processing Record 7 of Set 9 | sapao
# City not found. Skipping...
# Processing Record 8 of Set 9 | soderhamn
# Processing Record 9 of Set 9 | beloha
# Processing Record 10 of Set 9 | saint anthony
# Processing Record 11 of Set 9 | mangai
# Processing Record 12 of Set 9 | katangli
# Processing Record 13 of Set 9 | souillac
# Processing Record 14 of Set 9 | kabompo
# Processing Record 15 of Set 9 | san juan de abajo
# Processing Record 16 of Set 9 | kiunga
# Processing Record 17 of Set 9 | zapolyarnyy
# Processing Record 18 of Set 9 | mount isa
# Processing Record 19 of Set 9 | shingu
# Processing Record 20 of Set 9 | jagodina
# Processing Record 21 of Set 9 | nykoping
# Processing Record 22 of Set 9 | urumqi
# Processing Record 23 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 24 of Set 9 | north branch
# Processing Record 25 of Set 9 | taburi
# City not found. Skipping...
# Processing Record 26 of Set 9 | sioux lookout
# Processing Record 27 of Set 9 | salinas
# Processing Record 28 of Set 9 | port hardy
# Processing Record 29 of Set 9 | okhotsk
# Processing Record 30 of Set 9 | guerrero
# Processing Record 31 of Set 9 | lata
# Processing Record 32 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 33 of Set 9 | rocky mountain house
# Processing Record 34 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 35 of Set 9 | billings
# Processing Record 36 of Set 9 | dehui
# Processing Record 37 of Set 9 | miri
# Processing Record 38 of Set 9 | garliava
# Processing Record 39 of Set 9 | meulaboh
# Processing Record 40 of Set 9 | fort saint james
# Processing Record 41 of Set 9 | victoria point
# Processing Record 42 of Set 9 | gat
# Processing Record 43 of Set 9 | lumeje
# Processing Record 44 of Set 9 | rafai
# Processing Record 45 of Set 9 | dali
# Processing Record 46 of Set 9 | ust-ilimsk
# Processing Record 47 of Set 9 | lakes entrance
# Processing Record 48 of Set 9 | stokmarknes
# Processing Record 49 of Set 9 | marabba
# Processing Record 50 of Set 9 | sakakah
# Processing Record 1 of Set 10 | bakreswar
# Processing Record 2 of Set 10 | atlantic city
# Processing Record 3 of Set 10 | humberto de campos
# Processing Record 4 of Set 10 | galdar
# Processing Record 5 of Set 10 | san patricio
# Processing Record 6 of Set 10 | tiarei
# Processing Record 7 of Set 10 | kibala
# Processing Record 8 of Set 10 | bahia honda
# Processing Record 9 of Set 10 | qui nhon
# Processing Record 10 of Set 10 | san isidro
# Processing Record 11 of Set 10 | penarroya-pueblonuevo
# Processing Record 12 of Set 10 | durham
# Processing Record 13 of Set 10 | libertador general san martin
# Processing Record 14 of Set 10 | sao joao da barra
# Processing Record 15 of Set 10 | krasnoselkup
# Processing Record 16 of Set 10 | goderich
# Processing Record 17 of Set 10 | iquitos
# Processing Record 18 of Set 10 | kingman
# Processing Record 19 of Set 10 | motala
# Processing Record 20 of Set 10 | muli
# Processing Record 21 of Set 10 | melnikovo
# Processing Record 22 of Set 10 | nelson bay
# Processing Record 23 of Set 10 | vostok
# Processing Record 24 of Set 10 | tara
# Processing Record 25 of Set 10 | amahai
# Processing Record 26 of Set 10 | indramayu
# Processing Record 27 of Set 10 | musoma
# Processing Record 28 of Set 10 | wagar
# Processing Record 29 of Set 10 | conceicao do araguaia
# Processing Record 30 of Set 10 | kizhinga
# Processing Record 31 of Set 10 | lasa
# Processing Record 32 of Set 10 | longlac
# City not found. Skipping...
# Processing Record 33 of Set 10 | yangjiang
# Processing Record 34 of Set 10 | itaituba
# Processing Record 35 of Set 10 | nauta
# Processing Record 36 of Set 10 | tigil
# Processing Record 37 of Set 10 | teguldet
# Processing Record 38 of Set 10 | dolores
# Processing Record 39 of Set 10 | gazli
# Processing Record 40 of Set 10 | livramento
# Processing Record 41 of Set 10 | karamea
# City not found. Skipping...
# Processing Record 42 of Set 10 | sidrolandia
# Processing Record 43 of Set 10 | port hedland
# Processing Record 44 of Set 10 | mugur-aksy
# Processing Record 45 of Set 10 | tagusao
# Processing Record 46 of Set 10 | voi
# Processing Record 47 of Set 10 | batouri
# Processing Record 48 of Set 10 | izumo
# Processing Record 49 of Set 10 | dabeiba
# Processing Record 50 of Set 10 | ponta do sol
# Processing Record 1 of Set 11 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 2 of Set 11 | rzhanitsa
# Processing Record 3 of Set 11 | caravelas
# Processing Record 4 of Set 11 | vila do maio
# Processing Record 5 of Set 11 | ixtenco
# Processing Record 6 of Set 11 | finote selam
# Processing Record 7 of Set 11 | rovaniemi
# Processing Record 8 of Set 11 | tasiilaq
# Processing Record 9 of Set 11 | necochea
# Processing Record 10 of Set 11 | khunti
# Processing Record 11 of Set 11 | nanakuli
# Processing Record 12 of Set 11 | santa rosa
# Processing Record 13 of Set 11 | vestmannaeyjar
# Processing Record 14 of Set 11 | moussoro
# Processing Record 15 of Set 11 | bereznik
# Processing Record 16 of Set 11 | yar-sale
# Processing Record 17 of Set 11 | victor harbor
# Processing Record 18 of Set 11 | cividale del friuli
# Processing Record 19 of Set 11 | oyama
# Processing Record 20 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 21 of Set 11 | limoux
# Processing Record 22 of Set 11 | vangaindrano
# Processing Record 23 of Set 11 | dublin
# Processing Record 24 of Set 11 | erzin
# Processing Record 25 of Set 11 | ambilobe
# Processing Record 26 of Set 11 | pandan
# Processing Record 27 of Set 11 | shimanovsk
# Processing Record 28 of Set 11 | firozpur jhirka
# Processing Record 29 of Set 11 | methoni
# Processing Record 30 of Set 11 | kloulklubed
# Processing Record 31 of Set 11 | hundested
# Processing Record 32 of Set 11 | almeirim
# Processing Record 33 of Set 11 | mwinilunga
# Processing Record 34 of Set 11 | altay
# Processing Record 35 of Set 11 | shimoda
# Processing Record 36 of Set 11 | avera
# Processing Record 37 of Set 11 | kahului
# Processing Record 38 of Set 11 | brigantine
# Processing Record 39 of Set 11 | srandakan
# Processing Record 40 of Set 11 | stornoway
# Processing Record 41 of Set 11 | itarema
# Processing Record 42 of Set 11 | kolyvan
# Processing Record 43 of Set 11 | havre-saint-pierre
# Processing Record 44 of Set 11 | alice springs
# Processing Record 45 of Set 11 | moron
# Processing Record 46 of Set 11 | bud
# Processing Record 47 of Set 11 | kaura namoda
# Processing Record 48 of Set 11 | secunda
# Processing Record 49 of Set 11 | taicheng
# Processing Record 50 of Set 11 | tautira
# Processing Record 1 of Set 12 | fort-shevchenko
# Processing Record 2 of Set 12 | utiroa
# City not found. Skipping...
# Processing Record 3 of Set 12 | ulladulla
# Processing Record 4 of Set 12 | yerbogachen
# Processing Record 5 of Set 12 | college
# Processing Record 6 of Set 12 | kalat
# Processing Record 7 of Set 12 | xuddur
# Processing Record 8 of Set 12 | yining
# Processing Record 9 of Set 12 | belyy yar
# Processing Record 10 of Set 12 | dhidhdhoo
# Processing Record 11 of Set 12 | norheimsund
# Processing Record 12 of Set 12 | celestun
# Processing Record 13 of Set 12 | matagami
# Processing Record 14 of Set 12 | artyk
# City not found. Skipping...
# Processing Record 15 of Set 12 | pisco
# Processing Record 16 of Set 12 | tosno
# Processing Record 17 of Set 12 | dzilam gonzalez
# Processing Record 18 of Set 12 | kathu
# Processing Record 19 of Set 12 | mysliborz
# Processing Record 20 of Set 12 | tiznit
# Processing Record 21 of Set 12 | kichera
# Processing Record 22 of Set 12 | voh
# Processing Record 23 of Set 12 | linguere
# Processing Record 24 of Set 12 | shenzhen
# Processing Record 25 of Set 12 | uribia
# Processing Record 26 of Set 12 | ubinskoye
# Processing Record 27 of Set 12 | cabedelo
# Processing Record 28 of Set 12 | kelowna
# Processing Record 29 of Set 12 | yenagoa
# Processing Record 30 of Set 12 | solnechnyy
# Processing Record 31 of Set 12 | port lincoln
# Processing Record 32 of Set 12 | mersing
# Processing Record 33 of Set 12 | dasoguz
# Processing Record 34 of Set 12 | capao da canoa
# Processing Record 35 of Set 12 | nuuk
# Processing Record 36 of Set 12 | terrace
# Processing Record 37 of Set 12 | sao pedro
# Processing Record 38 of Set 12 | ciudad bolivar
# Processing Record 39 of Set 12 | rostock
# Processing Record 40 of Set 12 | babstovo
# Processing Record 41 of Set 12 | sault sainte marie
# Processing Record 42 of Set 12 | acin
# City not found. Skipping...
# Processing Record 43 of Set 12 | lianran
# Processing Record 44 of Set 12 | louth
# Processing Record 45 of Set 12 | broome
# Processing Record 46 of Set 12 | voskresenskoye
# Processing Record 47 of Set 12 | lar gerd
# City not found. Skipping...
# Processing Record 48 of Set 12 | salekhard
# Processing Record 49 of Set 12 | ban nahin
# Processing Record 50 of Set 12 | steinbach
# Processing Record 1 of Set 13 | ous
# Processing Record 2 of Set 13 | brae
# Processing Record 3 of Set 13 | kamenka
# Processing Record 4 of Set 13 | popova
# Processing Record 5 of Set 13 | sompeta
# Processing Record 6 of Set 13 | rafraf
# Processing Record 7 of Set 13 | kuopio
# Processing Record 8 of Set 13 | hobyo
# Processing Record 9 of Set 13 | naryan-mar
# Processing Record 10 of Set 13 | havoysund
# Processing Record 11 of Set 13 | ventspils
# Processing Record 12 of Set 13 | egvekinot
# Processing Record 13 of Set 13 | zhanaozen
# Processing Record 14 of Set 13 | pangody
# Processing Record 15 of Set 13 | alofi
# Processing Record 16 of Set 13 | bilma
# Processing Record 17 of Set 13 | ercis
# Processing Record 18 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 19 of Set 13 | port jervis
# Processing Record 20 of Set 13 | yelandur
# Processing Record 21 of Set 13 | camalu
# Processing Record 22 of Set 13 | soyo
# Processing Record 23 of Set 13 | gay
# Processing Record 24 of Set 13 | tabuk
# Processing Record 25 of Set 13 | san carlos de bariloche
# Processing Record 26 of Set 13 | mingyue
# Processing Record 27 of Set 13 | balimo
# City not found. Skipping...
# Processing Record 28 of Set 13 | ouargaye
# Processing Record 29 of Set 13 | maine-soroa
# Processing Record 30 of Set 13 | ukiah
# Processing Record 31 of Set 13 | labrea
# Processing Record 32 of Set 13 | marsh harbour
# Processing Record 33 of Set 13 | krutinka
# Processing Record 34 of Set 13 | novaya zaimka
# Processing Record 35 of Set 13 | khatima
# Processing Record 36 of Set 13 | paita
# Processing Record 37 of Set 13 | hokitika
# Processing Record 38 of Set 13 | norsup
# Processing Record 39 of Set 13 | saint-georges
# Processing Record 40 of Set 13 | brazzaville
# Processing Record 41 of Set 13 | kikwit
# Processing Record 42 of Set 13 | le port
# Processing Record 43 of Set 13 | derzhavinsk
# Processing Record 44 of Set 13 | sinnamary
# Processing Record 45 of Set 13 | san juan
# Processing Record 46 of Set 13 | deputatskiy
# Processing Record 47 of Set 13 | raudeberg
# Processing Record 48 of Set 13 | okha
# Processing Record 49 of Set 13 | shieli
# Processing Record 50 of Set 13 | port-gentil
# Processing Record 1 of Set 14 | sao mateus
# Processing Record 2 of Set 14 | amberg
# Processing Record 3 of Set 14 | santa marta
# Processing Record 4 of Set 14 | dawlatabad
# Processing Record 5 of Set 14 | satitoa
# City not found. Skipping...
# Processing Record 6 of Set 14 | panguna
# Processing Record 7 of Set 14 | aberdeen
# Processing Record 8 of Set 14 | mnogovershinnyy
# Processing Record 9 of Set 14 | kuragino
# Processing Record 10 of Set 14 | lhuntshi
# City not found. Skipping...
# Processing Record 11 of Set 14 | zhoukou
# Processing Record 12 of Set 14 | sinjar
# Processing Record 13 of Set 14 | bad doberan
# Processing Record 14 of Set 14 | lahat
# Processing Record 15 of Set 14 | abancay
# Processing Record 16 of Set 14 | saint-augustin
# Processing Record 17 of Set 14 | lagos
# Processing Record 18 of Set 14 | champasak
# Processing Record 19 of Set 14 | nichinan
# Processing Record 20 of Set 14 | kjollefjord
# Processing Record 21 of Set 14 | senj
# Processing Record 22 of Set 14 | palu
# Processing Record 23 of Set 14 | malanje
# Processing Record 24 of Set 14 | philippsburg
# Processing Record 25 of Set 14 | presidencia roque saenz pena
# Processing Record 26 of Set 14 | jiuquan
# Processing Record 27 of Set 14 | englewood
# Processing Record 28 of Set 14 | moose factory
# Processing Record 29 of Set 14 | mecca
# Processing Record 30 of Set 14 | yumen
# Processing Record 31 of Set 14 | marawi
# Processing Record 32 of Set 14 | tukrah
# Processing Record 33 of Set 14 | arrecife
# Processing Record 34 of Set 14 | mapiripan
# Processing Record 35 of Set 14 | kyshtovka
# Processing Record 36 of Set 14 | tokonou
# Processing Record 37 of Set 14 | garissa
# Processing Record 38 of Set 14 | churapcha
# Processing Record 39 of Set 14 | la palma
# Processing Record 40 of Set 14 | santa maria
# Processing Record 41 of Set 14 | paamiut
# Processing Record 42 of Set 14 | port macquarie
# Processing Record 43 of Set 14 | vreed en hoop
# City not found. Skipping...
# Processing Record 44 of Set 14 | turmalina
# Processing Record 45 of Set 14 | bull savanna
# Processing Record 46 of Set 14 | zabid
# Processing Record 47 of Set 14 | balikpapan
# Processing Record 48 of Set 14 | simao
# Processing Record 49 of Set 14 | kimbe
# Processing Record 50 of Set 14 | djambala
# Processing Record 1 of Set 15 | waingapu
# Processing Record 2 of Set 15 | narsaq
# Processing Record 3 of Set 15 | neiafu
# Processing Record 4 of Set 15 | chumikan
# Processing Record 5 of Set 15 | tottori
# Processing Record 6 of Set 15 | mount darwin
# Processing Record 7 of Set 15 | salaverry
# Processing Record 8 of Set 15 | kyzyl-suu
# Processing Record 9 of Set 15 | eyrarbakki
# Processing Record 10 of Set 15 | shouguang
# Processing Record 11 of Set 15 | buraydah
# Processing Record 12 of Set 15 | visby
# Processing Record 13 of Set 15 | champerico
# Processing Record 14 of Set 15 | arsenyev
# Processing Record 15 of Set 15 | medowie
# Processing Record 16 of Set 15 | kolosovka
# Processing Record 17 of Set 15 | tarakan
# Processing Record 18 of Set 15 | ndele
# Processing Record 19 of Set 15 | muros
# Processing Record 20 of Set 15 | boguchany
# Processing Record 21 of Set 15 | high rock
# Processing Record 22 of Set 15 | wajir
# Processing Record 23 of Set 15 | herat
# Processing Record 24 of Set 15 | hunza
# City not found. Skipping...
# Processing Record 25 of Set 15 | aflu
# City not found. Skipping...
# Processing Record 26 of Set 15 | yarmouth
# Processing Record 27 of Set 15 | bosaso
# Processing Record 28 of Set 15 | kysyl-syr
# Processing Record 29 of Set 15 | omsukchan
# Processing Record 30 of Set 15 | caldwell
# Processing Record 31 of Set 15 | bouza
# Processing Record 32 of Set 15 | boden
# Processing Record 33 of Set 15 | pallasovka
# Processing Record 34 of Set 15 | aborlan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 676

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Rikitea      PF -23.1203 -134.9692     76.86        84          96
# 1    Port Moresby      PG  -9.4431  147.1797     74.98        91         100
# 2     Honningsvag      NO  70.9821   25.9704     40.53        70           5
# 3     San Joaquin      US  37.9333 -121.3011     88.99        29           1
# 4            Fare      PF -16.7000 -151.0167     80.53        72          22
# 5         Sambava      MG -14.2667   50.1667     71.83        88          38
# 6   Chateaubelair      VC  13.2833  -61.2500     79.81        75         100
# 7      Bredasdorp      ZA -34.5322   20.0403     59.45        32           5
# 8  Cabo San Lucas      MX  22.8909 -109.9124    102.81        52           7
# 9       Cape Town      ZA -33.9258   18.4232     69.12        25          20
#
#    Wind Speed Current Description
# 0       15.68     overcast clouds
# 1        9.40     overcast clouds
# 2        4.68           clear sky
# 3       14.97           clear sky
# 4       10.25          few clouds
# 5       10.47    scattered clouds
# 6       12.10     overcast clouds
# 7        6.35           clear sky
# 8        9.89           clear sky
# 9       10.22          few clouds

# %%
output_data_file = "Weather_Database/WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label='City_ID')
